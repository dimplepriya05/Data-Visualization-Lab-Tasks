# %% [markdown]
# <a href="https://colab.research.google.com/github/dimplepriya05/Data-Visualization-Lab-Tasks/blob/main/DV_Task_2a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("/content/StudentsPerformance.csv")
print(df['gender'].value_counts())
print(df['gender'].value_counts(normalize=True) * 100)
sns.countplot(x='gender', data=df)
plt.title("Bar Chart - Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
gender_counts = df['gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart - Gender Distribution")
plt.axis('equal')
plt.show()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64
# gender
# female    51.8
# male      48.2
# Name: proportion, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("/content/StudentsPerformance.csv")
print(df.head())
math_scores = df['math score']
reading_scores = df['reading score']
writing_scores = df['writing score']
print("Math Score Summary:")
print(math_scores.describe())
print("\nReading Score Summary:")
print(reading_scores.describe())
print("\nWriting Score Summary:")
print(writing_scores.describe())
sns.histplot(math_scores, bins=10, kde=False)
plt.title("Histogram of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.show()
sns.boxplot(x=math_scores)
plt.title("Box Plot of Math Scores")
plt.xlabel("Math Score")
plt.show()
sns.kdeplot(math_scores, shade=True)
plt.title("Density Plot of Math Scores")
plt.xlabel("Math Score")
plt.show()
sns.rugplot(math_scores, height=0.1)
plt.title("Rug Plot of Math Scores")
plt.xlabel("Math Score")
plt.show()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# Math Score Summary:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64
#
# Reading Score Summary:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64
#
# Writing Score Summary:
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64
# /tmp/ipython-input-1041157482.py:24: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(math_scores, shade=True)

# %% [markdown]
# # New section
