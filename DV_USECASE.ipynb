# %% [markdown]
# <a href="https://colab.research.google.com/github/dimplepriya05/Data-Visualization-Lab-Tasks/blob/main/DV_USECASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read dataset from CSV file
df = pd.read_csv('Department_Performance_Yearly.csv')

# Print first 10 records as a table
print("=== Company Department Yearly Performance Dataset ===")
print(df.head(10))

# Set seaborn theme for pastel colors
sns.set_theme(style="whitegrid", palette="pastel")

# Calculate average yearly performance for each department
df['Average'] = df.iloc[:, 1:13].mean(axis=1)

# Bar plot: Average yearly performance
plt.figure(figsize=(12,6))
sns.barplot(x='Department', y='Average', data=df)
plt.title('Average Yearly Performance of Departments', fontsize=16)
plt.ylabel('Average Performance')
plt.xlabel('Department')
plt.show()


# Scatter plot: Performance distribution per month
plt.figure(figsize=(14,7))
for dept in df['Department']:
    plt.scatter(months, df[df['Department']==dept].iloc[0,1:13], s=100, label=dept)
plt.title('Monthly Performance Scatter Plot of Departments', fontsize=16)
plt.xlabel('Month')
plt.ylabel('Performance')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()



# Pie chart: Average yearly performance contribution by each department

df['Average'] = df.iloc[:, 1:13].mean(axis=1)
plt.figure(figsize=(8,8))
plt.pie(df['Average'], labels=df['Department'], autopct='%1.1f%%', startangle=140, colors=plt.cm.Pastel1.colors)
plt.title('Average Yearly Performance Contribution by Department', fontsize=16)
plt.show()

# Box plot: Performance distribution across months for all departments
plt.figure(figsize=(12,6))
sns.boxplot(data=df.iloc[:,1:13])
plt.title('Box Plot of Monthly Performance Across Departments', fontsize=16)
plt.xlabel('Month')
plt.ylabel('Performance')
plt.show()
# Out:
# === Company Department Yearly Performance Dataset ===
#          Department  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  \
# 0                HR   75   78   80   82   85   83   84   86   88   87   89
# 1             Sales   88   85   87   89   90   92   91   93   94   92   95
# 2                IT   92   90   93   94   95   96   97   98   99   97  100
# 3           Finance   85   88   86   87   89   90   92   91   93   94   95
# 4         Marketing   80   82   85   86   88   89   87   90   91   92   93
# 5        Operations   78   79   81   82   84   85   86   87   88   89   90
# 6               R&D   90   91   92   93   94   95   96   97   98   96   99
# 7  Customer Support   70   72   74   75   77   78   79   81   82   83   85
# 8         Logistics   76   78   77   79   80   81   82   83   84   85   86
# 9             Admin   82   83   85   86   88   87   88   89   90   91   92
#
#    Dec
# 0   90
# 1   96
# 2   99
# 3   96
# 4   94
# 5   91
# 6  100
# 7   86
# 8   87
# ...
